# %%
import pandas as pd
import numpy as np

# %%
titanic = pd.read_csv('EDA02titanic.csv')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %% [markdown]
# # Transpose of Df

# %%
titanic.T
# Out:
#            0        1       2       3     4       5        6       7    \
# survived     0        1       1       1     0       0        0       0
# pclass       3        1       3       1     3       3        1       3
# sex       male   female  female  female  male    male     male    male
# age       22.0     38.0    26.0    35.0  35.0     NaN     54.0     2.0
# sibsp        1        1       0       1     0       0        0       3
# parch        0        0       0       0     0       0        0       1
# fare      7.25  71.2833   7.925    53.1  8.05  8.4583  51.8625  21.075
# embarked     S        C       S       S     S       Q        S       S
# deck       NaN        C     NaN       C   NaN     NaN        E     NaN
#
#               8        9    ...     881      882   883   884     885   886  \
# survived        1        1  ...       0        0     0     0       0     0
# pclass          3        2  ...       3        3     2     3       3     2
# ...

# %%
titanic.transpose()
# Out:
#            0        1       2       3     4       5        6       7    \
# survived     0        1       1       1     0       0        0       0
# pclass       3        1       3       1     3       3        1       3
# sex       male   female  female  female  male    male     male    male
# age       22.0     38.0    26.0    35.0  35.0     NaN     54.0     2.0
# sibsp        1        1       0       1     0       0        0       3
# parch        0        0       0       0     0       0        0       1
# fare      7.25  71.2833   7.925    53.1  8.05  8.4583  51.8625  21.075
# embarked     S        C       S       S     S       Q        S       S
# deck       NaN        C     NaN       C   NaN     NaN        E     NaN
#
#               8        9    ...     881      882   883   884     885   886  \
# survived        1        1  ...       0        0     0     0       0     0
# pclass          3        2  ...       3        3     2     3       3     2
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic = titanic.transpose()

# %%
titanic.head()
# Out:
#            0       1       2       3     4     5     6     7       8    \
# survived     0       1       1       1     0     0     0     0       1
# pclass       3       1       3       1     3     3     1     3       3
# sex       male  female  female  female  male  male  male  male  female
# age       22.0    38.0    26.0    35.0  35.0   NaN  54.0   2.0    27.0
# sibsp        1       1       0       1     0     0     0     3       0
#
#              9    ...   881     882   883   884     885   886     887     888  \
# survived       1  ...     0       0     0     0       0     0       1       0
# pclass         2  ...     3       3     2     3       3     2       1       3
# sex       female  ...  male  female  male  male  female  male  female  female
# age         14.0  ...  33.0    22.0  28.0  25.0    39.0  27.0    19.0     NaN
# sibsp          1  ...     0       0     0     0       0     0       0       1
#
#            889   890
# survived     1     0
# pclass       1     3
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, survived to deck
# Columns: 891 entries, 0 to 890
# dtypes: object(891)
# memory usage: 63.0+ KB

# %%
titanic = titanic.T

# %%
titanic.head()
# Out:
#   survived pclass     sex   age sibsp parch     fare embarked deck
# 0        0      3    male  22.0     1     0     7.25        S  NaN
# 1        1      1  female  38.0     1     0  71.2833        C    C
# 2        1      3  female  26.0     0     0    7.925        S  NaN
# 3        1      1  female  35.0     1     0     53.1        S    C
# 4        0      3    male  35.0     0     0     8.05        S  NaN

# %% [markdown]
# ### After transposing original df 2 times, the value of each column is taken as object type

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    object
#  1   pclass    891 non-null    object
#  2   sex       891 non-null    object
#  3   age       714 non-null    object
#  4   sibsp     891 non-null    object
#  5   parch     891 non-null    object
#  6   fare      891 non-null    object
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: object(9)
# memory usage: 62.8+ KB

# %%
titanic.groupby(['sex', 'pclass']).survived.mean()
# Out:
# sex     pclass
# female  1         0.968085
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.135447
# Name: survived, dtype: float64

# %%
titanic = pd.read_csv('EDA02titanic.csv')
titanic.head(2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C

# %% [markdown]
# # Proper use of transpose

# %%
titanic.groupby(['sex', 'pclass']).survived.mean().unstack().T
# Out:
# sex       female      male
# pclass
# 1       0.968085  0.368852
# 2       0.921053  0.157407
# 3       0.500000  0.135447

# %%
titanic.T.T.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    object
#  1   pclass    891 non-null    object
#  2   sex       891 non-null    object
#  3   age       714 non-null    object
#  4   sibsp     891 non-null    object
#  5   parch     891 non-null    object
#  6   fare      891 non-null    object
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: object(9)
# memory usage: 62.8+ KB

# %%
table1 = pd.read_csv('table1.csv')
table1.head(8)
# Out:
#   Country   Medal  Count
# 0     AFG  Bronze      2
# 1     AHO  Silver      1
# 2     ALG  Bronze      8
# 3     ALG    Gold      5
# 4     ALG  Silver      2
# 5     ANZ  Bronze      5
# 6     ANZ    Gold     20
# 7     ANZ  Silver      4

# %%
table1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 347 entries, 0 to 346
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  347 non-null    object
#  1   Medal    347 non-null    object
#  2   Count    347 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 8.3+ KB

# %%
table1.shape
# Out:
# (347, 3)

# %% [markdown]
# # Pivot

# %%
table1.pivot(index='Country', columns= 'Medal', values =  'Count')
# Out:
# Medal    Bronze   Gold  Silver
# Country
# AFG         2.0    NaN     NaN
# AHO         NaN    NaN     1.0
# ALG         8.0    5.0     2.0
# ANZ         5.0   20.0     4.0
# ARG        91.0   69.0    99.0
# ...         ...    ...     ...
# VIE         NaN    NaN     2.0
# YUG       118.0  143.0   174.0
# ZAM         1.0    NaN     1.0
# ZIM         1.0   18.0     4.0
# ZZX        10.0   23.0    15.0
#
# [147 rows x 3 columns]

# %% [raw]
# Here, pivot arange a df according to our needs.
# Here, we have set index to country and column to medal and the value of medal to count column

# %%
table1_pivot = table1.pivot(index='Country', columns= 'Medal', values =  'Count').fillna(0)

# %%
table1_pivot
# Out:
# Medal    Bronze   Gold  Silver
# Country
# AFG         2.0    0.0     0.0
# AHO         0.0    0.0     1.0
# ALG         8.0    5.0     2.0
# ANZ         5.0   20.0     4.0
# ARG        91.0   69.0    99.0
# ...         ...    ...     ...
# VIE         0.0    0.0     2.0
# YUG       118.0  143.0   174.0
# ZAM         1.0    0.0     1.0
# ZIM         1.0   18.0     4.0
# ZZX        10.0   23.0    15.0
#
# [147 rows x 3 columns]

# %% [raw]
# Same as above. (Different Method)

# %%
table1.set_index(['Country', 'Medal']).unstack(fill_value = 0)
# Out:
#          Count
# Medal   Bronze Gold Silver
# Country
# AFG          2    0      0
# AHO          0    0      1
# ALG          8    5      2
# ANZ          5   20      4
# ARG         91   69     99
# ...        ...  ...    ...
# VIE          0    0      2
# YUG        118  143    174
# ZAM          1    0      1
# ZIM          1   18      4
# ZZX         10   23     15
#
# [147 rows x 3 columns]

# %% [markdown]
# # Limitation of Pivot - Cannot deal with duplicate datas

# %%
table2 = pd.read_csv('table2.csv')

# %%
table2.head()
# Out:
#   Country  Year   Medal  Count
# 0     AFG  2008  Bronze      1
# 1     AFG  2012  Bronze      1
# 2     AHO  1988  Silver      1
# 3     ALG  1984  Bronze      2
# 4     ALG  1992  Bronze      1

# %%
 table2.pivot(index = 'Country', columns = 'Medal', values = 'Count') )
# Out:
#   File "<ipython-input-35-8925df19a6e0>", line 1
#     table2.pivot(index = 'Country', columns = 'Medal', values = 'Count') )
#                                                                          ^
# SyntaxError: unmatched ')'

# %% [raw]
# If we have to do it then we can do above line by following below line:

# %%
table2.groupby(['Country', "Year", 'Medal']).Count.sum().unstack().fillna(0)
# Out:
# Medal         Bronze  Gold  Silver
# Country Year
# AFG     2008     1.0   0.0     0.0
#         2012     1.0   0.0     0.0
# AHO     1988     0.0   0.0     1.0
# ALG     1984     2.0   0.0     0.0
#         1992     1.0   1.0     0.0
# ...              ...   ...     ...
# ZIM     2004     1.0   1.0     1.0
#         2008     0.0   1.0     3.0
# ZZX     1896     2.0   2.0     2.0
#         1900     8.0  18.0     8.0
#         1904     0.0   3.0     5.0
#
# [1157 rows x 3 columns]

# %% [markdown]
# # Pivot_table

# %%
table2
# Out:
#      Country  Year   Medal  Count
# 0        AFG  2008  Bronze      1
# 1        AFG  2012  Bronze      1
# 2        AHO  1988  Silver      1
# 3        ALG  1984  Bronze      2
# 4        ALG  1992  Bronze      1
# ...      ...   ...     ...    ...
# 2542     ZZX  1900  Bronze      8
# 2543     ZZX  1900    Gold     18
# 2544     ZZX  1900  Silver      8
# 2545     ZZX  1904    Gold      3
# 2546     ZZX  1904  Silver      5
#
# [2547 rows x 4 columns]

# %%
table2.pivot_table(index = 'Country', columns = 'Medal', values = 'Count', aggfunc = 'sum', fill_value = 0, margins = True, margins_name = 'Total')
# Out:
# Medal    Bronze   Gold  Silver  Total
# Country
# AFG           2      0       0      2
# AHO           0      0       1      1
# ALG           8      5       2     15
# ANZ           5     20       4     29
# ARG          91     69      99    259
# ...         ...    ...     ...    ...
# YUG         118    143     174    435
# ZAM           1      0       1      2
# ZIM           1     18       4     23
# ZZX          10     23      15     48
# Total     10369  10484   10308  31161
#
# [148 rows x 4 columns]

# %%
#same output different method
agg = table2.groupby(['Country', 'Medal']).Count.sum().unstack(fill_value = 0)

# %%
agg.head()
# Out:
# Medal    Bronze  Gold  Silver
# Country
# AFG           2     0       0
# AHO           0     0       1
# ALG           8     5       2
# ANZ           5    20       4
# ARG          91    69      99

# %%
agg['All'] = agg.sum(axis = 1)

# %%
agg.loc['All'] = agg.sum(axis = 0)

# %%
agg
# Out:
# Medal    Bronze   Gold  Silver    All
# Country
# AFG           2      0       0      2
# AHO           0      0       1      1
# ALG           8      5       2     15
# ANZ           5     20       4     29
# ARG          91     69      99    259
# ...         ...    ...     ...    ...
# YUG         118    143     174    435
# ZAM           1      0       1      2
# ZIM           1     18       4     23
# ZZX          10     23      15     48
# All       10369  10484   10308  31161
#
# [148 rows x 4 columns]

# %% [markdown]
# # CrossTab

# %%
titanic = pd.read_csv('EDA02titanic.csv')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
pd.crosstab(titanic.sex, titanic.pclass, margins = True, normalize = False)
# Out:
# pclass    1    2    3  All
# sex
# female   94   76  144  314
# male    122  108  347  577
# All     216  184  491  891

# %%
#same method different output
titanic.groupby(['sex', 'pclass']).pclass.count().unstack()
# Out:
# pclass    1    2    3
# sex
# female   94   76  144
# male    122  108  347

# %%
pd.crosstab(index = titanic.sex, columns = titanic.pclass, values = titanic.age, aggfunc = 'mean')
# Out:
# pclass          1          2          3
# sex
# female  34.611765  28.722973  21.750000
# male    41.281386  30.740707  26.507589

# %%
titanic.pivot_table(index = 'sex', columns = 'pclass', values = 'age', aggfunc = 'mean')
# Out:
# pclass          1          2          3
# sex
# female  34.611765  28.722973  21.750000
# male    41.281386  30.740707  26.507589

# %%
titanic.groupby(['sex', 'pclass']).age.mean().unstack()
# Out:
# pclass          1          2          3
# sex
# female  34.611765  28.722973  21.750000
# male    41.281386  30.740707  26.507589

# %%
pd.crosstab(index = titanic.sex, columns = titanic.pclass, values = titanic.fare, aggfunc = 'sum', margins = True, normalize = False )
# Out:
# pclass           1          2          3         All
# sex
# female   9975.8250  1669.7292  2321.1086  13966.6628
# male     8201.5875  2132.1125  4393.5865  14727.2865
# All     18177.4125  3801.8417  6714.6951  28693.9493

# %%
summer = pd.read_csv('EDA02summer.csv')
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31165 entries, 0 to 31164
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Athlete     31165 non-null  object
#  5   Country     31161 non-null  object
#  6   Gender      31165 non-null  object
#  7   Event       31165 non-null  object
#  8   Medal       31165 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
pd.crosstab(index = [summer.Year, summer.Country], columns = summer.Medal, aggfunc = 'count', values = summer.Medal, margins = True).fillna(0)
# Out:
# Medal          Bronze     Gold   Silver    All
# Year Country
# 1896 AUS          0.0      2.0      0.0      2
#      AUT          2.0      2.0      1.0      5
#      DEN          3.0      1.0      2.0      6
#      FRA          2.0      5.0      4.0     11
#      GBR          2.0      2.0      3.0      7
# ...               ...      ...      ...    ...
# 2012 UKR         12.0      9.0      4.0     25
#      USA         46.0    147.0     57.0    250
#      UZB          2.0      1.0      0.0      3
#      VEN          0.0      1.0      0.0      1
# All           10369.0  10484.0  10308.0  31161
#
# [1158 rows x 4 columns]

# %%
summer.pivot_table(index = ['Year', 'Country'], columns = 'Medal', aggfunc = 'count', values = 'Athlete', fill_value = 0, margins = True)
# Out:
# Medal         Bronze   Gold  Silver    All
# Year Country
# 1896 AUS           0      2       0      2
#      AUT           2      2       1      5
#      DEN           3      1       2      6
#      FRA           2      5       4     11
#      GBR           2      2       3      7
# ...              ...    ...     ...    ...
# 2012 UKR          12      9       4     25
#      USA          46    147      57    250
#      UZB           2      1       0      3
#      VEN           0      1       0      1
# All            10369  10484   10308  31161
#
# [1158 rows x 4 columns]

# %%
summer.groupby(['Year', 'Country', 'Medal']).Medal.count().unstack(fill_value = 0)
# Out:
# Medal         Bronze  Gold  Silver
# Year Country
# 1896 AUS           0     2       0
#      AUT           2     2       1
#      DEN           3     1       2
#      FRA           2     5       4
#      GBR           2     2       3
# ...              ...   ...     ...
# 2012 UGA           0     1       0
#      UKR          12     9       4
#      USA          46   147      57
#      UZB           2     1       0
#      VEN           0     1       0
#
# [1157 rows x 3 columns]

# %% [markdown]
# # Melt- opposite of pivot

# %%
table_2012 = pd.read_csv('table_2012.csv')
table_2012.head()
# Out:
#   Country  Gold  Silver  Bronze
# 0     USA   147      57      46
# 1     CHN    56      44      28
# 2     GBR    48      30      48
# 3     RUS    47      32      51
# 4     GER    45      28      21

# %%
table_2012.melt(id_vars = 'Country', value_vars = ['Gold', 'Silver', 'Bronze'], var_name = 'Medal', value_name = 'Count')
# Out:
#    Country   Medal  Count
# 0      USA    Gold    147
# 1      CHN    Gold     56
# 2      GBR    Gold     48
# 3      RUS    Gold     47
# 4      GER    Gold     45
# 5      FRA    Gold     30
# 6      NED    Gold     21
# 7      AUS    Gold     19
# 8      KOR    Gold     18
# 9      MEX    Gold     18
# 10     ITA    Gold     16
# 11     NOR    Gold     15
# 12     CRO    Gold     15
# 13     BRA    Gold     14
# 14     HUN    Gold     12
# 15     NZL    Gold      9
# 16     UKR    Gold      9
# 17     JAM    Gold      8
# 18     JPN    Gold      7
# 19     RSA    Gold      6
# 20     USA  Silver     57
# 21     CHN  Silver     44
# 22     GBR  Silver     30
# 23     RUS  Silver     32
# 24     GER  Silver     28
# 25     FRA  Silver     30
# 26     NED  Silver     29
# 27     AUS  Silver     36
# 28     KOR  Silver     13
# 29     MEX  Silver      5
# 30     ITA  Silver     22
# 31     NOR  Silver      1
# 32     CRO  Silver      4
# 33     BRA  Silver     34
# ...

# %%
melt_2012 = table_2012.melt(id_vars = 'Country', value_vars = ['Gold', 'Silver', 'Bronze'], var_name = 'Medal', value_name = 'Count')

# %%
melt_2012.pivot(index = 'Country', columns = 'Medal', values = 'Count').sort_values('Gold', ascending = False)
# Out:
# Medal    Bronze  Gold  Silver
# Country
# USA          46   147      57
# CHN          28    56      44
# GBR          48    48      30
# RUS          51    47      32
# GER          21    45      28
# FRA          22    30      30
# NED          19    21      29
# AUS          59    19      36
# KOR          32    18      13
# MEX           3    18       5
# ITA          30    16      22
# NOR           1    15       1
# CRO          16    15       4
# BRA          11    14      34
# HUN           6    12       8
# NZL          14     9       3
# UKR          12     9       4
# JAM           8     8       9
# JPN          33     7      44
# RSA           1     6       2
