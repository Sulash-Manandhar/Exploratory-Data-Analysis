# %%
import pandas as pd
import numpy as np

# %%
titanic = pd.read_csv('EDA02titanic.csv')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Plot

# %%
titanic.plot(subplots=True, figsize =(15,12),sharex=False, sharey = False)
plt.show() #used for displaying the ouput

# %%
titanic.age.plot(figsize=(15,12),fontsize=18, c= 'g',linestyle=':')
plt.title('Titanic - Ages', fontsize = 18)
plt.legend(loc=0, fontsize = 15)
plt.xlabel('Passenger No', fontsize = 18)
plt.ylabel('Age', fontsize = 18)
plt.grid()
plt.show()

# %% [markdown]
# # Xlim, Ylim - limit plot

# %%
titanic.age.plot(figsize=(15,12),fontsize=18, c= 'r',linestyle=':',xlim = (200, 400), ylim = (20,40))
plt.title('Titanic - Ages', fontsize = 18)
plt.legend(loc=0, fontsize = 15)
plt.xlabel('Passenger No', fontsize = 18)
plt.ylabel('Age', fontsize = 18)
plt.grid()
plt.show()

# %% [markdown]
# # Xtick , Ytick

# %%
xtick = [x for x in range(0, 901, 50)]
xtick
# Out:
# [0,
#  50,
#  100,
#  150,
#  200,
#  250,
#  300,
#  350,
#  400,
#  450,
#  500,
#  550,
#  600,
#  650,
#  700,
#  750,
#  800,
#  850,
#  900]

# %%
ytick = [y for y in range(0, 81, 5)]
ytick
# Out:
# [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80]

# %%
titanic.age.plot(figsize=(15,12),fontsize=18, c= 'r',linestyle=':', xticks = xtick, yticks = ytick,rot = 5)
plt.title('Titanic - Ages', fontsize = 18)
plt.legend(loc=0, fontsize = 15)
plt.xlabel('Passenger No', fontsize = 18)
plt.ylabel('Age', fontsize = 18)
plt.grid()
plt.show()

# %% [markdown]
# # Style

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn')

# %%
titanic.age.plot(figsize=(15,12),fontsize=18, c= 'r',linestyle=':', xticks = xtick, yticks = ytick,rot = 5)
plt.title('Titanic - Ages', fontsize = 18)
plt.legend(loc=0, fontsize = 15)
plt.xlabel('Passenger No', fontsize = 18)
plt.ylabel('Age', fontsize = 18)
plt.show()

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.age.value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: age, Length: 88, dtype: int64

# %% [markdown]
# # Bins and hist

# %%
titanic.age.plot(kind = 'hist', figsize = (15,12), fontsize = 18, bins = 20)
plt.show()

# %% [markdown]
# # Cumulative

# %%
titanic.age.plot(kind = 'hist', figsize = (15,12), fontsize = 18, bins = 20, cumulative = True)
plt.show()

# %%
summer = pd.read_csv('EADsummer_2012.csv', index_col = 'Country')
summer
# Out:
#          Medal
# Country
# USA        250
# RUS        130
# CHN        128
# GBR        126
# AUS        114
# GER         94
# JPN         84
# FRA         82
# NED         69
# ITA         68
# ESP         65
# KOR         63
# BRA         59
# CAN         57
# CRO         35
# HUN         26
# MEX         26
# NZL         26
# JAM         25
# UKR         25
# Others     393

# %% [markdown]
# # Bargraph

# %%
summer.Medal.plot(kind = 'bar', figsize = (12,8), fontsize = 18)
plt.show()

# %% [markdown]
# # Piechart

# %%
summer.Medal.plot(kind = 'pie', figsize = (12,8), fontsize = 18)
plt.show()

# %% [markdown]
# # Scatterplot

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.plot(kind = 'scatter', figsize = (15,12), x = 'age', y = 'fare')
plt.show()

# %%
titanic.plot(kind = 'scatter', figsize = (15,12), x = 'age', y = 'fare', c = 'pclass', marker ='x',colormap = 'viridis')
plt.show()
